# %%
x=[1,2,3,4,5,6]

# %%
x.reverse()

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x.pop(2)
# Out:
# 3

# %%
x
# Out:
# [1, 2, 4, 5, 6]

# %%
x.append(4)

# %%
x
# Out:
# [1, 2, 4, 5, 6, 4, 4]

# %%
x.sort()

# %%
x
# Out:
# [1, 2, 4, 4, 4, 5, 6]

# %%
x+x
# Out:
# [1, 2, 4, 4, 4, 5, 6, 1, 2, 4, 4, 4, 5, 6]

# %%
x.sort()
x
# Out:
# [1, 2, 4, 4, 4, 5, 6]

# %%
import numpy as np

a = np.array([
    [32, 45, 67, 43],
    [56, 78, 90, 34],
    [23, 36, 47, 92],
    [29, 25,  1,  8]
])

print(a)
# Out:
# [[32 45 67 43]
#  [56 78 90 34]
#  [23 36 47 92]
#  [29 25  1  8]]

# %%
a[1:,1:3]
# Out:
# array([[78, 90],
#        [36, 47],
#        [25,  1]])

# %%
a[2:,:2]
# Out:
# array([[23, 36],
#        [29, 25]])

# %%
a[0:,1:3]
# Out:
# array([[45, 67],
#        [78, 90],
#        [36, 47],
#        [25,  1]])

# %%
print(a[2:4, 1:3])
# Out:
# [[36 47]
#  [25  1]]

# %%
print(a[1:4, 1:4])
# Out:
# [[78 90 34]
#  [36 47 92]
#  [25  1  8]]

# %%
a.shape
# Out:
# (4, 4)

# %%
a.var
# Out:
# <function ndarray.var>

# %%
a.std()
# Out:
# np.float64(25.90819127225982)

# %%
a.min()
# Out:
# np.int64(1)

# %%
a.max()
# Out:
# np.int64(92)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 a.multiply()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'multiply'
