# %%
def square(num):
    return num*num
square(4)
# Out:
# 16

# %%
def info(name):
    print("hello",name)

# %%
info("musa")
# Out:
# hello musa

# %%
def greet(name="Guest"):
    print("hello",name)
greet("ayan")
# Out:
# hello ayan

# %%
greet('aiza')
# Out:
# hello aiza

# %%
#key words arguements (key,value)
#position arguments(*)

# %%
def employee_details(**kwargs):
    s=input("enter s")
    
    print(kwargs)
employee_details(name="Musa",Age=21,city="chikodi")
# Out:
# enter s s
# {'name': 'Musa', 'Age': 21, 'city': 'chikodi'}

# %%
def register_user(**user):
    print("User Registrations Details:")
    for key,value in user.items():
        print(key,"=",value)
register_user(username="musa-04",email="musa@gmail.com",phone=9874563211)
# Out:
# User Registrations Details:
# username = musa-04
# email = musa@gmail.com
# phone = 9874563211

# %%
# lambda functions:
# it is a small and anonymous functions which is used to work with huge amount of data and to perform
# data mainupulations

# %%
squares=lambda x:x**2
print(squares(7))
# Out:
# 49

# %%
cubes=lambda y:y**3
print(cubes(6))
# Out:
# 216

# %%
6*6*6
# Out:
# 216

# %%
# 
numbers=[1,2,3,4,5]
squares=list(map(lambda x:x**2,numbers))

# %%
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
cubes=list(map(lambda x:x**3,[1,2,3,4,5]))
cubes
# Out:
# [1, 8, 27, 64, 125]

# %%
salary=[100000,25000,32000,43000,55000]
bonus=list(map(lambda x:x+5000,salary)
bonus
# Out:
#   Cell In[37], line 2
#     bonus=list(map(lambda x:x+5000,salary)
#               ^
# SyntaxError: '(' was never closed

# %%
numbers=[10,20,30,40,45,55,65,75]
evens=list(filter(lambda x:x%2==0,numbers))

# %%
evens
# Out:
# [10, 20, 30, 40]

# %%
numbers
# Out:
# [10, 20, 30, 40, 45, 55, 65, 75]

# %%
students=[
    ("Alice",24),
    ("Bob",19),
    ("Charan",22)
]
students.sort(key=lambda student:student[1])
print(students)
# Out:
# [('Bob', 19), ('Charan', 22), ('Alice', 24)]

# %%
employees=[
    {"name":"joice","salary":50000},
    {"name":"musa","salary":40000}
]
employees.sort(key=lambda emp:emp["salary"])

# %%
def check_even_odd(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

number = int(input("Enter a number: "))

result = check_even_odd(number)

print("The number is", result)
# Out:
# Enter a number:  55
# The number is Odd

# %%
def sum_upto_n(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total

n = int(input("Enter a number: "))
print("Sum is:", sum_upto_n(n))
# Out:
# Enter a number:  122
# Sum is: 7503

# %%
def find_max(numbers):
    return max(numbers)

nums = [10, 45, 23, 89, 34]
print("Maximum number is:", find_max(nums))
# Out:
# Maximum number is: 89
