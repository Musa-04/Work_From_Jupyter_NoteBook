# %%
# #oops concepts
# object
# class 
# encapsulation
# polymorphism
# inheritance
# abstractions

# %%
# class: blue print of creating objects where it defines variables and functions

# %%
# example car is class defines color ,model and the speed

# %%
# constructor it is a speacial method that is automatcially called when an object is created 
# it it mainly used to initialze values to object variable

# %%
class car:
    def  __init__(self,brand,speed):
        self.brand=brand
        self.speed=speed

    def drive(self):
        print(f"{self.brand} is driving at {self.speed} km/h")
print("class created succesfully")
# Out:
# class created succesfully

# %%
car1=car("BMW",120)

# %%
car1.drive()
# Out:
# BMW is driving at 120 km/h

# %%
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        return self.__balance
    def set_balance(self):

# %%
acc=BankAccount(50000
               )

# %%
acc.get_balance()
# Out:
# 5000

# %%
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        return self.__balance
    def set_balance(self,amount):
        if amount>=0:
            self.__balance=amount

# %%
acc=BankAccount(10000)

# %%
acc.set_balance(120000)

# %%
acc.get_balance()
# Out:
# 120000

# %%
#user and password
class user:
    def __init__(self,username,password):
        self.username=username
        self._password=password

# %%
def get_password(user):
    return '*******'

# %%
u=user("admin",123)

# %%
print(u)

# %%
class Animal:
    def speak(self):
        print("Animal maked sound")
class Dog(Animal):
    def speak(self):
        print("dog braks only anyone hurts")
class Zebra(Animal):
    def speak(self):
        print("zebra bray")

# %%
z=Zebra()
d=Dog()

# %%
z.speak()
# Out:
# zebra bray

# %%
d.speak()
# Out:
# dog braks only anyone hurts

# %%
# Base class
class Payment:
    def pay(self, amount):
        pass


# Child class 1
class UPI(Payment):
    def pay(self, amount):
        print(f"Paid ₹{amount} using UPI")


# Child class 2
class CreditCard(Payment):
    def pay(self, amount):
        print(f"Paid ₹{amount} using Credit Card")


# Creating objects
payments = [
    UPI(),
    CreditCard(),
    UPI(),
    CreditCard()
]

amounts = [500, 1200, 250, 800]


# Using for loop
for pay_method, amt in zip(payments, amounts):
    pay_method.pay(amt)
# Out:
# Paid ₹500 using UPI
# Paid ₹1200 using Credit Card
# Paid ₹250 using UPI
# Paid ₹800 using Credit Card

# %%
# Student class
class Student:
    def __init__(self, name, rollnumber, marks):
        self.name = name
        self.rollnumber = rollnumber
        self.marks = marks

    def display(self):
        print(f"Name: {self.name} | Roll: {self.rollnumber} | Marks: {self.marks}")



students = []

n = 3   # number of students

for i in range(n):
    print(f"\nEnter details for Student {i+1}")

    name = input("Enter name: ")
    roll = int(input("Enter roll number: "))
    marks = float(input("Enter marks: "))

    # create object and store
    s = Student(name, roll, marks)
    students.append(s)



print("\n---- Student Details ----")

for student in students:
    student.display()
# Out:
# Enter details for Student 1
# Enter name:  a
# Enter roll number:  1
# Enter marks:  1
# Enter details for Student 2
# Enter name:  b
# Enter roll number:  2
# Enter marks:  2
# Enter details for Student 3
# Enter name:  c
# Enter roll number:  3
# Enter marks:  3
# ---- Student Details ----
# Name: a | Roll: 1 | Marks: 1.0
# Name: b | Roll: 2 | Marks: 2.0
# Name: c | Roll: 3 | Marks: 3.0
